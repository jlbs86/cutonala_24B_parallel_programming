# %% [markdown]
# <a href="https://colab.research.google.com/github/jlbs86/cutonala_24B_parallel_programming/blob/ezequiel_develop/Delanuay_Triangulation_Point_to_Point.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Instalar mpi4py
# !pip install mpi4py
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 466.2/466.2 kB 12.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for mpi4py: filename=mpi4py-4.0.1-cp310-cp310-linux_x86_64.whl size=4266343 sha256=b0d1cf1f18e4df706efda108adf5b30d69c25f1614aae3c13b744b498e09078e
#   Stored in directory: /root/.cache/pip/wheels/3c/ca/13/13218a83854023ccec184e3af482f0f038b434aa32c19afee8
# Successfully built mpi4py
# ...

# %%
# !apt-get install -y -qq openmpi-bin openmpi-common libopenmpi-dev

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#import os
#os.listdir('/content/drive/My Drive/')
# Out:
# ['Mall_Customers.csv',
#  'Classroom',
#  '1° Fundamentos de la Ciencia computacional ',
#  'Propiedades de la materia final (1).gslides',
#  'Propiedades de la materia final.gslides',
#  'Reseña de la Iliada.docx',
#  'Tarea Dispositivos de Almacenamiento.gdoc',
#  'Desarrollo de Competencias Digitales',
#  'Los presocráticos.docx',
#  'PRIMER EXAMEN DE PRECALCULO 21A (1).gdoc',
#  'PRIMER EXAMEN DE PRECALCULO 21A.gdoc',
#  'Capitulo 7.docx',
#  '20210409_231438.jpg',
#  'naturaleza y lo natural.docx',
#  'WhatsApp Image 2021-04-23 at 12.29.51 PM (1).jpeg',
#  'WhatsApp Image 2021-04-23 at 12.29.51 PM (2).jpeg',
#  'WhatsApp Image 2021-04-23 at 12.29.51 PM (3).jpeg',
#  'WhatsApp Image 2021-04-23 at 12.29.51 PM (4).jpeg',
#  'WhatsApp Image 2021-04-23 at 12.29.51 PM.jpeg',
#  'Reseña critica del apartado Guillermo de Occam.docx',
#  'Reglas para la direccion del espiitu.docx',
#  'Emu8086 (1)',
#  'Emu8086',
#  'plantilla Hoja de prensentacion.gdoc',
# ...

# %%
# !mpiexec --oversubscribe --allow-run-as-root -n 16 python /content/drive/My\ Drive/Delanuay_Triangulation_Point_to_Point.py

# %% [markdown]
# /content/drive/My Drive/Delanuay_Triangulation_Point_to_Point.py

# %%
from IPython.display import Image
Image('/content/delaunay_triangulation.png')

# %%
# !mpiexec --oversubscribe --allow-run-as-root -n 16 python /content/drive/My\ Drive/delaunay_broadcast.py

# %% [markdown]
# /content/drive/My Drive/delaunay_broadcast.py

# %%
Image('/content/delaunay_triangulation__collective_communication_broadcast.png')

# %%
# !mpiexec --oversubscribe --allow-run-as-root -n 16 python /content/drive/My\ Drive/delaunay_scattering.py

# %% [markdown]
# /content/drive/My Drive/delaunay_scattering.py

# %%
Image('/content/delaunay_triangulation__collective_communication_scattering.png')

# %%
# !mpiexec --oversubscribe --allow-run-as-root -n 16 python /content/drive/My\ Drive/delaunay_gatgering.py

# %% [markdown]
# /content/drive/My Drive/delaunay_gatgering.py

# %%
Image('/content/delaunay_triangulation__collective_communication_gathering.png')

# %%
# !mpiexec --oversubscribe --allow-run-as-root -n 16 python /content/drive/My\ Drive/delaunay_barrier.py

# %% [markdown]
# /content/drive/My Drive/delaunay_barrier.py

# %%
Image('/content/delaunay_triangulation__collective_communication_barrier.png')

# %%
# !mpiexec --oversubscribe --allow-run-as-root -n 16 python /content/drive/My\ Drive/delaunay_rank.py

# %% [markdown]
# /content/drive/My Drive/delaunay_rank.py

# %%
Image('/content/delaunay_triangulation__collective_communication_rank.png')

# %%
#import os
#os.listdir()
# Out:
# ['.config', 'drive', 'delaunay_triangulation.png', 'sample_data']
