# %%
! pip install mpi4py
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 464.8/464.8 kB 12.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for mpi4py: filename=mpi4py-4.0.0-cp310-cp310-linux_x86_64.whl size=4266261 sha256=5cc8e9eae047a045a2a824eafcfa23df04f9d8af27da894148137991624222e3
#   Stored in directory: /root/.cache/pip/wheels/96/17/12/83db63ee0ae5c4b040ee87f2e5c813aea4728b55ec6a37317c
# Successfully built mpi4py
# ...

# %%
! mpiexec --oversubscribe --allow-run-as-root -n 4 python /content/sample_data/example.py
# Out:
# Estado de 0: Hilo 0 activo
# Estado de 1: Hilo 1 activo
# Estado de 2: Hilo 2 activo
# Estado de 3: Hilo 3 activo
# Recibo en 3: Hilo 1 activo
# Estado de 0: Hilo 0 activo
# Estado de 0: Hilo 0 activo
# Estado de 1: Hilo 1 activo
# Estado de 0: Hilo 0 activo
# Recibo en 0: Hilo 0 activo
# Estado de 2: Hilo 2 activo
# Recibo en 0: Hilo 2 activo
# Estado de 3: Hilo 3 activo
# Recibo en 3: Hilo 2 activo
# Recibo en 0: Hilo 1 activo
# Recibo en 0: Hilo 3 activo
# Estado de 1: Hilo 1 activo
# Recibo en 1: Hilo 1 activo
# Estado de 1: Hilo 1 activo
# Recibo en 1: Hilo 0 activo
# Recibo en 2: Hilo 1 activo
# Estado de 2: Hilo 2 activo
# Recibo en 2: Hilo 0 activo
# Recibo en 2: Hilo 2 activo
# Estado de 2: Hilo 2 activo
# Recibo en 1: Hilo 2 activo
# Estado de 3: Hilo 3 activo
# Recibo en 3: Hilo 0 activo
# Recibo en 2: Hilo 3 activo
# Estado de 3: Hilo 3 activo
# Recibo en 1: Hilo 3 activo
# Recibo en 3: Hilo 3 activo
# Estado de 3: Hilo 3 activo
# Estado de 0: Hilo 0 activo
# ...
